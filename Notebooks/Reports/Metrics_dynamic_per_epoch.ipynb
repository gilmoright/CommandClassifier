# %%
import os
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
REPORTS_DIR = "/s/ls4/users/grartem/RL_robots/CommandClassifier/models/"

# %%
fig, axes  = plt.subplots(1,1)
experimentName = "rubert_tiny_multilabel"
for fold_i in range(5):
    y_macto_hist = []
    for epoch_i in range(1, 11):
        with open(os.path.join(REPORTS_DIR, experimentName, "fold_{}".format(fold_i), "reports", "epoch-{}_avg_report.json".format(epoch_i)), "r") as f:
            report = json.load(f)
            y_macto_hist.append(report['correct_samples_perc'])
    axes.plot(range(1, 11), y_macto_hist, label=fold_i)
    #break
axes.set_title("y_macro_f1 for 5 folds on 10 epoch rubert-tiny-multilabel, all classes")
axes.set_ylabel("y_macro_f1")
axes.set_xlabel("epoch")
fig.set_size_inches(15,6)
fig.legend()
plt.show()

# %%
fig, axes  = plt.subplots(1,1)
experimentName = "rubert_tiny_multilabel"
for fold_i in range(5):
    y_macto_hist = []
    for epoch_i in range(1, 11):
        with open(os.path.join(REPORTS_DIR, experimentName, "fold_{}".format(fold_i), "reports", "epoch-{}_avg_report.json".format(epoch_i)), "r") as f:
            report = json.load(f)
            y_macto_hist.append(report['avg_macro_f1'])
    axes.plot(range(1, 11), y_macto_hist, label=fold_i)
    #break
axes.set_title("y_macro_f1 for 5 folds on 10 epoch rubert-tiny-multilabel, all classes")
axes.set_ylabel("y_macro_f1")
axes.set_xlabel("epoch")
fig.set_size_inches(15,6)
fig.legend()
plt.show()

# %%
fig, axes  = plt.subplots(1,1)
experimentName = "rubert_tiny_multilabel"
for fold_i in range(5):
    y_macto_hist = []
    for epoch_i in range(1, 11):
        with open(os.path.join(REPORTS_DIR, experimentName, "fold_{}".format(fold_i), "reports", "epoch-{}_avg_report.json".format(epoch_i)), "r") as f:
            report = json.load(f)
            y_macto_hist.append(report['avg_acc'])
    axes.plot(range(1, 11), y_macto_hist, label=fold_i)
    #break
axes.set_title("y_macro_f1 for 5 folds on 10 epoch rubert-tiny-multilabel, all classes")
axes.set_ylabel("y_macro_f1")
axes.set_xlabel("epoch")
fig.set_size_inches(15,6)
fig.legend()
plt.show()

# %%
fig, axes  = plt.subplots(1,1)
experimentName = "MyMultiTiny2_data2"
for fold_i in range(5):
    y_macto_hist = []
    for epoch_i in range(1, 11):
        with open(os.path.join(REPORTS_DIR, experimentName, "fold_{}".format(fold_i), "reports", "epoch-{}_avg_report.json".format(epoch_i)), "r") as f:
            report = json.load(f)
            y_macto_hist.append(report['correct_samples_perc'])
    axes.plot(range(1, 11), y_macto_hist, label=fold_i)
    #break
axes.set_title("y_macro_f1 for 5 folds on 10 epoch rubert-tiny-multilabel, all classes")
axes.set_ylabel("y_macro_f1")
axes.set_xlabel("epoch")
fig.set_size_inches(15,6)
fig.legend()
plt.show()

# %%
fig, axes  = plt.subplots(1,1)
experimentName = "MyMultiTiny2_data3v2"
for fold_i in range(5):
    y_macto_hist = []
    for epoch_i in range(1, 21):
        with open(os.path.join(REPORTS_DIR, experimentName, "fold_{}".format(fold_i), "reports", "epoch-{}_avg_report.json".format(epoch_i)), "r") as f:
            report = json.load(f)
            y_macto_hist.append(report['correct_samples_perc'])
    axes.plot(range(1, 21), y_macto_hist, label="фолд {}".format(fold_i))
    #break
#axes.set_title("correct tuples % for 5 folds on 20 epoch rubert-tiny2-multilabel, all classes")
axes.set_title("Изменение % правильно предсказанных кортежей за 20 эпох для 5 фолдов")
axes.set_ylabel("% правильно предсказанных кортежей")
axes.set_xlabel("Эпоха")
fig.set_size_inches(11,5)
fig.legend()
plt.show()

# %%
fig, axes  = plt.subplots(1,1)
experimentName = "MyMultiTiny2_data3v2"
for fold_i in range(5):
    y_macto_hist = []
    for epoch_i in range(1, 21):
        with open(os.path.join(REPORTS_DIR, experimentName, "fold_{}".format(fold_i), "reports", "epoch-{}_avg_report.json".format(epoch_i)), "r") as f:
            report = json.load(f)
            y_macto_hist.append(report['avg_macro_f1'])
    axes.plot(range(1, 21), y_macto_hist, label="фолд {}".format(fold_i))
    #break
axes.set_title("Изменение оценки macro f1 для всех классов на 5 фолдах за 20 эпох")
axes.set_ylabel("macro f1")
axes.set_xlabel("Эпоха")
fig.set_size_inches(11,5)
fig.legend()
plt.show()

# %%
fig, axes  = plt.subplots(1,1)
experimentName = "MyMultiTiny2_data3v2"
for fold_i in range(5):
    y_macto_hist = []
    for epoch_i in range(1, 21):
        with open(os.path.join(REPORTS_DIR, experimentName, "fold_{}".format(fold_i), "reports", "epoch-{}_avg_report.json".format(epoch_i)), "r") as f:
            report = json.load(f)
            y_macto_hist.append(report['[action]_macrof1'])
    axes.plot(range(1, 21), y_macto_hist, label="фолд {}".format(fold_i))
    #break
axes.set_title("Изменение оценки macro f1 для классов действий на 5 фолдах за 20 эпох")
axes.set_ylabel("macro f1 для класса действия")
axes.set_xlabel("Эпоха")
fig.set_size_inches(11,5)
fig.legend()
plt.show()
